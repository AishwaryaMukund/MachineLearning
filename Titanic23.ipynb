# %%
import os
import pandas as pd
from sklearn.tree import DecisionTreeClassifier

DATA_PATH = "C:/Users/Aishu/Documents/GitHub/MachineLearning/datasets"
def load_titanic_data(data_path, file_name):
    csv_path = os.path.join(data_path, file_name)
    return pd.read_csv(csv_path)

train_set = load_titanic_data(DATA_PATH, "train.csv")
test_set = load_titanic_data(DATA_PATH, "test.csv")

train_set = train_set.drop(["Cabin", "Ticket"], axis=1)
test_set = test_set.drop(["Cabin", "Ticket"], axis=1)
train_set = train_set.drop(["Name", "PassengerId"], axis=1)
test_set = test_set.drop(["Name"], axis=1)
freq_embarked = train_set.Embarked.dropna().mode()[0]
freq_age = train_set.Age.dropna().mode()[0]
combine = [train_set, test_set]

for dataset in combine:
    dataset['Sex'] = dataset['Sex'].map( {'female': 1, 'male': 0} ).astype(int)
    dataset['Embarked'] = dataset['Embarked'].fillna(freq_embarked)
    dataset['Embarked'] = dataset['Embarked'].map({'C':0, 'Q':1, 'S':2}).astype(int)
    dataset['Age'] = dataset['Age'].fillna(freq_age)

X_train = train_set.drop("Survived", axis=1)
Y_train = train_set["Survived"]
X_test  = test_set.drop("PassengerId", axis=1).copy()
#X_train.shape, Y_train.shape, X_test.shape
X_test
# Out:
#      Pclass  Sex   Age  SibSp  Parch      Fare  Embarked
# 0         3    0  34.5      0      0    7.8292         1
# 1         3    1  47.0      1      0    7.0000         2
# 2         2    0  62.0      0      0    9.6875         1
# 3         3    0  27.0      0      0    8.6625         2
# 4         3    1  22.0      1      1   12.2875         2
# 5         3    0  14.0      0      0    9.2250         2
# 6         3    1  30.0      0      0    7.6292         1
# 7         2    0  26.0      1      1   29.0000         2
# 8         3    1  18.0      0      0    7.2292         0
# 9         3    0  21.0      2      0   24.1500         2
# 10        3    0  24.0      0      0    7.8958         2
# 11        1    0  46.0      0      0   26.0000         2
# 12        1    1  23.0      1      0   82.2667         2
# 13        2    0  63.0      1      0   26.0000         2
# 14        1    1  47.0      1      0   61.1750         2
# ...

# %%
from sklearn.model_selection import train_test_split

train_X, test_X, train_Y, test_Y = train_test_split(train_set, train_set['Survived'], test_size=0.2, random_state=42)

tree_classifier = DecisionTreeClassifier()
tree_classifier.fit(train_X, train_Y) 
y_pred = tree_classifier.predict(test_X)
print(sum(y_pred==test_Y))
print(len(test_Y))
print ("Accuracy on Training: ",sum(y_pred==test_Y)/len(test_Y))

train_X.head(10)

acc_decision_tree = round(tree_classifier.score(train_X, train_Y) * 100, 2)
acc_decision_tree

# %%
import os
import pandas as pd
from sklearn.tree import DecisionTreeClassifier

DATA_PATH = "C:/Users/Aishu/Documents/GitHub/MachineLearning/datasets"
def load_titanic_data(data_path, file_name):
    csv_path = os.path.join(data_path, file_name)
    return pd.read_csv(csv_path)

train_set = load_titanic_data(DATA_PATH, "train.csv")
test_set = load_titanic_data(DATA_PATH, "test.csv")

freq_embarked = train_set.Embarked.dropna().mode()[0]
freq_age = train_set.Age.dropna().mode()[0]
freq_fare = train_set.Fare.dropna().mode()[0]
combine = [train_set, test_set]
for dataset in combine:
    dataset['Embarked'] = dataset['Embarked'].fillna(freq_embarked)
    dataset['Embarked'] = dataset['Embarked'].map({'C':0, 'Q':1, 'S':2}).astype(int)
    dataset['Age'] = dataset['Age'].fillna(freq_age)
    dataset['Sex'] = dataset['Sex'].map( {'female': 1, 'male': 0} ).astype(int)
    dataset['Fare'] = dataset['Fare'].fillna(freq_fare)
    
train_data = train_set[["Pclass", "SibSp", "Parch",  "Fare", "Sex", "Embarked", 'Age']]
test_data = test_set[["Pclass", "SibSp", "Parch",  "Fare", "Sex", "Embarked", 'Age']]
#test_data['Survived'] = 0
#test_data['Survived'] = test_data.Survived.apply(lambda x: int(x))
test_set
# Out:
#      PassengerId  Pclass                                               Name  \
# 0            892       3                                   Kelly, Mr. James
# 1            893       3                   Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                          Myles, Mr. Thomas Francis
# 3            895       3                                   Wirz, Mr. Albert
# 4            896       3       Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5            897       3                         Svensson, Mr. Johan Cervin
# 6            898       3                               Connolly, Miss. Kate
# 7            899       2                       Caldwell, Mr. Albert Francis
# 8            900       3          Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 9            901       3                            Davies, Mr. John Samuel
# 10           902       3                                   Ilieff, Mr. Ylio
# ...

# %%
from sklearn.model_selection import train_test_split

train_X, test_X, train_Y, test_Y = train_test_split(train_data, train_set['Survived'], test_size=0.2, random_state=42)

tree_classifier = DecisionTreeClassifier()
tree_classifier.fit(train_X, train_Y) 
y_pred = tree_classifier.predict(test_X)
print ("Accuracy on Training: ",sum(y_pred==test_Y)/len(test_Y))

acc_decision_tree = round(tree_classifier.score(train_X, train_Y) * 100, 2)
acc_decision_tree
# Out:
# Accuracy on Training:  0.77094972067
# 97.890000000000001

# %%
final_test[['PassengerId', 'Survived']].to_csv('datasets/titanic_submission1.csv', index=False)
print (final_test[['PassengerId', 'Survived']].head())

# %%
y_pred = tree_classifier.predict(test_data)
test_data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-b94fd37a0f7b> in <module>()
# ----> 1 y_pred = tree_classifier.predict(test_data)
#       2 test_data
#
# ~\Anaconda3\lib\site-packages\sklearn\tree\tree.py in predict(self, X, check_input)
#     410         """
#     411         check_is_fitted(self, 'tree_')
# --> 412         X = self._validate_X_predict(X, check_input)
#     413         proba = self.tree_.predict(X)
#     414         n_samples = X.shape[0]
#
# ~\Anaconda3\lib\site-packages\sklearn\tree\tree.py in _validate_X_predict(self, X, check_input)
#     382                              "match the input. Model n_features is %s and "
#     383                              "input n_features is %s "
# --> 384                              % (self.n_features_, n_features))
#     385
#     386         return X
#
# ...
